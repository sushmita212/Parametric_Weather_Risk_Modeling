# %%
# # If your notebook is in 'notebooks/' and script is in 'src/'
# import sys
# sys.path.append("../src")

# from data_downloader import download_storm_data

# # Download and organize all files (or set limit=5 for testing)
# download_storm_data(output_dir="../data")

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/details/details_2020.csv.gz")
df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202006         24        1620         202006       24      1620
# 1           202006         20        1930         202006       20      1930
# 2           202006          3        1550         202006        3      1550
# 3           202006         19        1900         202006       19      1900
# 4           202006         20        1900         202006       20      1900
#
#    EPISODE_ID  EVENT_ID    STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0      149684    902190  GEORGIA          13  ...        1.0           W
# 1      149048    898391   KANSAS          20  ...        8.0          SE
# 2      149149    899120   KANSAS          20  ...       14.0          NW
# 3      149046    898383   KANSAS          20  ...        2.0         SSE
# 4      149048    898388   KANSAS          20  ...        1.0          SE
#
#        END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT   END_LON  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61278 entries, 0 to 61277
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     61278 non-null  int64
#  1   BEGIN_DAY           61278 non-null  int64
#  2   BEGIN_TIME          61278 non-null  int64
#  3   END_YEARMONTH       61278 non-null  int64
#  4   END_DAY             61278 non-null  int64
#  5   END_TIME            61278 non-null  int64
#  6   EPISODE_ID          61278 non-null  int64
#  7   EVENT_ID            61278 non-null  int64
#  8   STATE               61278 non-null  object
#  9   STATE_FIPS          61278 non-null  int64
#  10  YEAR                61278 non-null  int64
#  11  MONTH_NAME          61278 non-null  object
#  12  EVENT_TYPE          61278 non-null  object
#  13  CZ_TYPE             61278 non-null  object
#  14  CZ_FIPS             61278 non-null  int64
# ...

# %%
df.select_dtypes(include=['object']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61278 entries, 0 to 61277
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   STATE               61278 non-null  object
#  1   MONTH_NAME          61278 non-null  object
#  2   EVENT_TYPE          61278 non-null  object
#  3   CZ_TYPE             61278 non-null  object
#  4   CZ_NAME             61278 non-null  object
#  5   WFO                 61278 non-null  object
#  6   BEGIN_DATE_TIME     61278 non-null  object
#  7   CZ_TIMEZONE         61278 non-null  object
#  8   END_DATE_TIME       61278 non-null  object
#  9   DAMAGE_PROPERTY     48417 non-null  object
#  10  DAMAGE_CROPS        49170 non-null  object
#  11  SOURCE              61278 non-null  object
#  12  MAGNITUDE_TYPE      27166 non-null  object
#  13  FLOOD_CAUSE         6365 non-null   object
#  14  TOR_F_SCALE         1250 non-null   object
# ...

# %%
cols = ['SOURCE', 'DATA_SOURCE', 'CATEGORY','EPISODE_NARRATIVE', 'EVENT_NARRATIVE']
df[cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61278 entries, 0 to 61277
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SOURCE             61278 non-null  object
#  1   DATA_SOURCE        61278 non-null  object
#  2   CATEGORY           63 non-null     float64
#  3   EPISODE_NARRATIVE  61278 non-null  object
#  4   EVENT_NARRATIVE    49541 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 2.3+ MB

# %%
df.drop(columns=cols, errors='ignore', inplace=True)

# %%
df
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 0               202006         24        1620         202006       24
# 1               202006         20        1930         202006       20
# 2               202006          3        1550         202006        3
# 3               202006         19        1900         202006       19
# 4               202006         20        1900         202006       20
# ...                ...        ...         ...            ...      ...
# 61273           202008         10         845         202008       10
# 61274           202006          2        1402         202006        2
# 61275           202006          8        2337         202006        8
# 61276           202006          2        1723         202006        2
# 61277           202006          2        1730         202006        2
#
#        END_TIME  EPISODE_ID  EVENT_ID     STATE  STATE_FIPS  ...  BEGIN_RANGE  \
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# TOR_OTHER_CZ_NAME     61112
# TOR_OTHER_CZ_FIPS     61112
# TOR_OTHER_WFO         61112
# TOR_OTHER_CZ_STATE    61112
# TOR_F_SCALE           60028
# TOR_LENGTH            60028
# TOR_WIDTH             60028
# FLOOD_CAUSE           54913
# MAGNITUDE_TYPE        34112
# MAGNITUDE             26417
# END_LON               21517
# BEGIN_RANGE           21517
# BEGIN_AZIMUTH         21517
# BEGIN_LOCATION        21517
# END_RANGE             21517
# END_AZIMUTH           21517
# END_LOCATION          21517
# BEGIN_LAT             21517
# BEGIN_LON             21517
# END_LAT               21517
# DAMAGE_PROPERTY       12861
# DAMAGE_CROPS          12108
# BEGIN_DAY                 0
# BEGIN_YEARMONTH           0
# DEATHS_DIRECT             0
# INJURIES_INDIRECT         0
# BEGIN_TIME                0
# END_YEARMONTH             0
# END_DAY                   0
# END_TIME                  0
# EPISODE_ID                0
# EVENT_ID                  0
# STATE                     0
# ...

# %%
df['EVENT_TYPE'].value_counts()
# Out:
# EVENT_TYPE
# Thunderstorm Wind             19315
# Hail                           7677
# High Wind                      3682
# Flash Flood                    3569
# Winter Weather                 2910
# Marine Thunderstorm Wind       2887
# Flood                          2704
# Drought                        2244
# Winter Storm                   2102
# Heavy Snow                     1792
# Heavy Rain                     1450
# Tornado                        1250
# Strong Wind                    1193
# Heat                           1106
# Dense Fog                      1002
# Excessive Heat                  961
# Frost/Freeze                    878
# Tropical Storm                  714
# Blizzard                        515
# High Surf                       415
# Wildfire                        413
# Funnel Cloud                    264
# Lightning                       247
# Extreme Cold/Wind Chill         215
# Waterspout                      194
# ...
